# %% [markdown]
# <a href="https://colab.research.google.com/github/NadaHamdyMostafa/NLP/blob/main/LLM_load_Llama2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# this auto model that can used it to load any model from huggingFace

# %%
from transformers import AutoModelForCausalLM

# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 118.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 104.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 852.3 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 14.7 MB/s eta 0:00:00
# ...

# %%
model_id = "NousResearch/Llama-2-7b-chat-hf"

# %% [markdown]
# we do Quantization to model
# two option: 4bits,8bits,16bits,32bits to map ,based on it ,identify size of data
# 4bits:small size,32bits:bigest size
# but at the same time Quantization make performance decrease due to we not use all data ,we used small size of it

# %%
pip install accelerate

# %%
model = AutoModelForCausalLM.from_pretrained(model_id,load_in_4bit=True,device_map="auto",pad_token_id=0)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
import torch
from transformers import(
    AutoModelForCausalLM,#to load model
    AutoTokenizer,#
    BitsAndBytesConfig,#to make model use Quant during load and training
    HfArgumentParser,#
    TrainingArguments,
    pipeline,
    logging
)
from datasets import load_dataset#to load online dataset
from peft import LoraConfig,peft_model# side network that learn
from trl import SFTTrainer# to train model

# %%
from datasets import Dataset
import pandas as pd
data=pd.read_excel("new_qa.xlsx")

# %%
data
# Out:
#                                       Question  \
# 0                        who won the euro 2024
# 1       what is the result of spain vs england
# 2        what is the result of spain vs france
# 3          who reached the finals of euro 2024
# 4  who reached the quarter finals of euro 2024
#
#                                  Answer
# 0                                 spain
# 1                         2-1 for spain
# 2                         1-0 for spain
# 3                     spain and england
# 4  spain, england.france and netherland
